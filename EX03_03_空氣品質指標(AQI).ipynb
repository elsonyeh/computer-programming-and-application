# %% [markdown]
# <a href="https://colab.research.google.com/github/elsonyeh/computer-programming-and-application/blob/main/EX03_03_%E7%A9%BA%E6%B0%A3%E5%93%81%E8%B3%AA%E6%8C%87%E6%A8%99(AQI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Dataset: https://data.gov.tw/dataset/40448
# - 空氣品質相關定義：https://airtw.moenv.gov.tw/CHT/Information/Standard/AirQualityIndicatorNew.aspx

# %%
import pandas as pd
url = 'https://data.moenv.gov.tw/api/v2/aqx_P_432?api_key=9e565f9a-84dd-4e79-9097-d403cae1ea75&limit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df.head()
# Out:
#   sitename county  aqi pollutant status  so2    co  o3  o3_8hr  pm10  ...  \
# 0       基隆    基隆市   37       NaN     良好  1.2  0.36   1      19    26  ...
# 1       汐止    新北市   48       NaN     良好  0.7  0.28   4      21    23  ...
# 2       新店    新北市   40       NaN     良好  1.0  0.28  10      26    27  ...
# 3       土城    新北市   55     細懸浮微粒     普通  0.6  0.42   4      21    33  ...
# 4       板橋    新北市   33       NaN     良好  1.4  0.41  13      27    25  ...
#
#    wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg pm10_avg  \
# 0         0.4         291  2025/06/14 23:00:00     0.2       5.2       22
# 1         0.9          35  2025/06/14 23:00:00     0.1      10.1       21
# 2         1.7         193  2025/06/14 23:00:00     0.2       9.8       24
# 3         0.4         210  2025/06/14 23:00:00     0.3      14.0       28
# 4         1.3         117  2025/06/14 23:00:00     0.3       6.7       20
#
#   so2_avg   longitude   latitude  siteid
# 0       1  121.760056  25.129167       1
# 1       1  121.640810  25.066240       2
# 2       1  121.537778  24.977222       4
# 3       0  121.451861  24.982528       5
# 4       1  121.458667  25.012972       6
#
# [5 rows x 24 columns]

# %% [markdown]
# ###留下需要的欄位（'sitename', 'county','pollutant', 'status', 'aqi'）

# %%
df = df[['sitename', 'county', 'pollutant', 'status', 'aqi']]
df

# %% [markdown]
# ### 請找出除了空氣品質不良的測站（aqi > 100）

# %%
condition = df['aqi'] > 100
df[condition]
# Out:
# Empty DataFrame
# Columns: [sitename, county, aqi, pollutant, status, so2, co, o3, o3_8hr, pm10, pm2.5, no2, nox, no, wind_speed, wind_direc, publishtime, co_8hr, pm2.5_avg, pm10_avg, so2_avg, longitude, latitude, siteid]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# ### 查詢空氣污染指標物（pollutant）有那些？

# %%
df['pollutant'].unique()
# Out:
# array([nan, '細懸浮微粒', '二氧化氮', '懸浮微粒'], dtype=object)

# %% [markdown]
# ### 請找出高雄市的測站資料

# %%
condition = df['county'] == '高雄市'
df[condition]
# Out:
#    sitename county  aqi pollutant status  so2    co  o3  o3_8hr  pm10  ...  \
# 45       美濃    高雄市   37       NaN     良好  0.4  0.18  16      33    28  ...
# 46       橋頭    高雄市   43       NaN     良好  1.4  0.33   5      16    22  ...
# 47       仁武    高雄市   37       NaN     良好  0.4  0.26  12      17    27  ...
# 48       鳳山    高雄市   53     細懸浮微粒     普通  1.2  0.32  12      18    32  ...
# 49       大寮    高雄市   45       NaN     良好  0.6  0.16  12      24    37  ...
# 50       林園    高雄市   70      懸浮微粒     普通  0.0  0.06  24      27    35  ...
# 51       楠梓    高雄市   45       NaN     良好  3.6  0.25   5      15    30  ...
# 52       左營    高雄市   43       NaN     良好  1.4  0.50   1      13    27  ...
# 53       前金    高雄市   52      二氧化氮     普通  3.0  0.28   1      15    38  ...
# 54       前鎮    高雄市   45       NaN     良好  2.0  0.53   3      14    29  ...
# 55       小港    高雄市   48       NaN     良好  5.8  0.20   7      17    47  ...
# 68       復興    高雄市   43       NaN     良好  1.7  0.35   5      15    25  ...
# 79   高雄（湖內）    高雄市   50       NaN     良好  1.1  0.39   4      13    32  ...
#
#     wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg pm10_avg  \
# 45         0.7          52  2025/06/14 23:00:00     0.2       7.3       22
# 46         1.6         137  2025/06/14 23:00:00     0.2      10.4       26
# 47         0.8         123  2025/06/14 23:00:00     0.2       9.0       22
# 48         0.5          97  2025/06/14 23:00:00     0.3      13.1       23
# 49         0.7         138  2025/06/14 23:00:00     0.1      11.0       27
# 50         1.2         161  2025/06/14 23:00:00     0.0      11.0       48
# 51         1.4         154  2025/06/14 23:00:00     0.2       8.5       27
# 52         0.8         139  2025/06/14 23:00:00     0.2       8.3       25
# 53         2.9         187  2025/06/14 23:00:00     0.1       7.7       31
# 54         0.7         162  2025/06/14 23:00:00     0.3       8.1       24
# 55         0.9         126  2025/06/14 23:00:00     0.1       7.3       21
# 68         0.3         257  2025/06/14 23:00:00     0.1       5.6       19
# 79         1.6         153  2025/06/14 23:00:00     0.1       5.1       30
#
#    so2_avg   longitude   latitude  siteid
# 45       0  120.530542  22.883583      47
# 46       0  120.305689  22.757506      48
# 47       0  120.332631  22.689056      49
# 48       1  120.357422  22.628126      50
# 49       0  120.425311  22.564136      51
# 50       0  120.411750  22.479500      52
# 51       1  120.328289  22.733667      53
# 52       0  120.292917  22.674861      54
# 53       0  120.286761  22.633903      56
# 54       1  120.308334  22.604451      57
# 55       2  120.337736  22.565833      58
# 68       0  120.312017  22.608711      71
# 79       0  120.245350  22.879856     202
#
# [13 rows x 24 columns]

# %% [markdown]
# ### 計算各縣市的平均 AQI

# %%
df.groupby('county')['aqi'].mean().sort_values(ascending=False)
# Out:
# county
# 屏東縣    54.000000
# 新北市    48.250000
# 高雄市    47.000000
# 臺北市    46.428571
# 桃園市    44.666667
# 嘉義縣    41.000000
# 臺南市    41.000000
# 宜蘭縣    40.000000
# 新竹縣    39.000000
# 新竹市    38.000000
# 花蓮縣    38.000000
# 連江縣    38.000000
# 臺東縣    37.500000
# 基隆市    37.000000
# 澎湖縣    37.000000
# 苗栗縣    37.000000
# 雲林縣    36.500000
# 臺中市    36.333333
# 南投縣    36.250000
# 嘉義市    34.000000
# 金門縣    34.000000
# 彰化縣    32.600000
# Name: aqi, dtype: float64
